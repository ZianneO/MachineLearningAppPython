# %% [markdown]
# # Python Stats Assignment

# %% [markdown]
# ## Zianne Olverson

# %% [markdown]
# ### Import of modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
from scipy import stats
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.formula.api import ols

# %% [markdown]
# ## 3.1.1.2 Reading in data

# %%
data = pd.read_csv('brain_size.csv', sep=';', na_values='.')
print(data.head())
# Out:
#    Unnamed: 0  Gender  FSIQ  VIQ  PIQ  Weight  Height  MRI_Count
# 0           1  Female   133  132  124   118.0    64.5     816932
# 1           2    Male   140  150  124     NaN    72.5    1001121
# 2           3    Male   139  123  150   143.0    73.3    1038437
# 3           4    Male   133  129  128   172.0    68.8     965353
# 4           5  Female   137  132  134   147.0    65.0     951545

# %% [markdown]
# # Creating 3 arrays from the data

# %%
t = np.linspace(-6, 6, 20)
sin_t = np.sin(t)
cos_t = np.cos(t)

# %% [markdown]
# # Creating dataframe using 3 arrays

# %%
pd.DataFrame({'t':t, 'sin': sin_t, 'cos': cos_t})
# Out:
#            t       sin       cos
# 0  -6.000000  0.279415  0.960170
# 1  -5.368421  0.792419  0.609977
# 2  -4.736842  0.999701  0.024451
# 3  -4.105263  0.821291 -0.570509
# 4  -3.473684  0.326021 -0.945363
# 5  -2.842105 -0.295030 -0.955488
# 6  -2.210526 -0.802257 -0.596979
# 7  -1.578947 -0.999967 -0.008151
# 8  -0.947368 -0.811882  0.583822
# 9  -0.315789 -0.310567  0.950551
# 10  0.315789  0.310567  0.950551
# 11  0.947368  0.811882  0.583822
# 12  1.578947  0.999967 -0.008151
# 13  2.210526  0.802257 -0.596979
# 14  2.842105  0.295030 -0.955488
# 15  3.473684 -0.326021 -0.945363
# 16  4.105263 -0.821291 -0.570509
# 17  4.736842 -0.999701  0.024451
# 18  5.368421 -0.792419  0.609977
# 19  6.000000 -0.279415  0.960170

# %% [markdown]
# # Observing and manipulating the data

# %%
data.shape
# Out:
# (40, 8)

# %% [markdown]
# ### Data has 40 rows and 8 columns

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Gender', 'FSIQ', 'VIQ', 'PIQ', 'Weight', 'Height',
#        'MRI_Count'],
#       dtype='object')

# %% [markdown]
# # Printing gender names in columns

# %%
print(data['Gender'].head())
# Out:
# 0    Female
# 1      Male
# 2      Male
# 3      Male
# 4    Female
# Name: Gender, dtype: object

# %% [markdown]
# # Mean VIQ for females within the dataframe

# %%
data[data['Gender'] == 'Female'] ['VIQ'].mean()
# Out:
# np.float64(109.45)

# %% [markdown]
# # Grouping the dataframe by gender and displaying mean VIQ for both genders

# %%
groupby_gender = data.groupby('Gender')
for gender, value in groupby_gender['VIQ']:
      print((gender, value.mean()))
# Out:
# ('Female', np.float64(109.45))
# ('Male', np.float64(115.25))

# %% [markdown]
# # Display of mean stats from both genders

# %%
groupby_gender.mean()
# Out:
#         Unnamed: 0   FSIQ     VIQ     PIQ      Weight     Height  MRI_Count
# Gender
# Female       19.65  111.9  109.45  110.45  137.200000  65.765000   862654.6
# Male         21.35  115.0  115.25  111.60  166.444444  71.431579   954855.4

# %% [markdown]
# # Plotting the data

# %% [markdown]
# ### Plotting Scatter Matrix of Weight, Height and MRI Count data

# %%
scatter_matrix(data[['Weight', 'Height', 'MRI_Count']])
# Out:
# array([[<Axes: xlabel='Weight', ylabel='Weight'>,
#         <Axes: xlabel='Height', ylabel='Weight'>,
#         <Axes: xlabel='MRI_Count', ylabel='Weight'>],
#        [<Axes: xlabel='Weight', ylabel='Height'>,
#         <Axes: xlabel='Height', ylabel='Height'>,
#         <Axes: xlabel='MRI_Count', ylabel='Height'>],
#        [<Axes: xlabel='Weight', ylabel='MRI_Count'>,
#         <Axes: xlabel='Height', ylabel='MRI_Count'>,
#         <Axes: xlabel='MRI_Count', ylabel='MRI_Count'>]], dtype=object)

# %% [markdown]
# ### Plotting Scatter Matrix of PIQ, VIQ and FSIQ

# %%
scatter_matrix(data[['PIQ', 'VIQ', 'FSIQ']])
# Out:
# array([[<Axes: xlabel='PIQ', ylabel='PIQ'>,
#         <Axes: xlabel='VIQ', ylabel='PIQ'>,
#         <Axes: xlabel='FSIQ', ylabel='PIQ'>],
#        [<Axes: xlabel='PIQ', ylabel='VIQ'>,
#         <Axes: xlabel='VIQ', ylabel='VIQ'>,
#         <Axes: xlabel='FSIQ', ylabel='VIQ'>],
#        [<Axes: xlabel='PIQ', ylabel='FSIQ'>,
#         <Axes: xlabel='VIQ', ylabel='FSIQ'>,
#         <Axes: xlabel='FSIQ', ylabel='FSIQ'>]], dtype=object)

# %% [markdown]
# # 3.1.2 Hypothesis testing on the data

# %% [markdown]
# ## Student's t-tests

# %% [markdown]
# ### Testing value of population VIQ mean using 1-sample t-test

# %%
stats.ttest_1samp(data['VIQ'], 0)
# Out:
# TtestResult(statistic=np.float64(30.08809997084933), pvalue=np.float64(1.3289196468727879e-28), df=np.int64(39))

# %% [markdown]
# ### Testing difference across in VIQ populations using 2-sample t-test to determine significance

# %%
female_viq = data[data['Gender'] == 'Female'] ['VIQ']
male_viq = data[data['Gender'] == 'Male'] ['VIQ']

# %%
t_statistic, p_value = stats.ttest_ind(female_viq, male_viq)

# %%
print("T-Statistic:", t_statistic)
print("P-Value:", p_value)
# Out:
# T-Statistic: -0.7726161723275012
# P-Value: 0.44452876778583217

# %% [markdown]
# ## 2-sample t-test to determine if FSIQ and PIQ are sig dif

# %%
stats.ttest_ind(data['FSIQ'], data['PIQ'])
# Out:
# TtestResult(statistic=np.float64(0.465637596380964), pvalue=np.float64(0.6427725009414841), df=np.float64(78.0))

# %% [markdown]
# ### Results for this aren't accurate because FSIQ and PIQ are measured in the same individual so a paired test needs to be run instead

# %% [markdown]
# # Paired tests to determine if FSIQ and PIQ are different in individuals

# %%
stats.ttest_rel(data['FSIQ'], data['PIQ'])
# Out:
# TtestResult(statistic=np.float64(1.7842019405859857), pvalue=np.float64(0.08217263818364236), df=np.int64(39))

# %% [markdown]
# ## 1-sample t-test to determine if FSIQ and PIQ are different in individuals

# %% [markdown]
# ### Same results as the paired test

# %%
stats.ttest_1samp(data['FSIQ'] - data['PIQ'], 0)
# Out:
# TtestResult(statistic=np.float64(1.7842019405859857), pvalue=np.float64(0.08217263818364236), df=np.int64(39))

# %% [markdown]
# ## Wilcoxon signed-rank test to relax Gaussian errors

# %%
stats.wilcoxon(data['FSIQ'], data['PIQ'])
# Out:
# WilcoxonResult(statistic=np.float64(274.5), pvalue=np.float64(0.10659492713506856))

# %% [markdown]
# # 3.1.3 Creating simulated data for a linear model, multiple factors and ANOVA

# %%
x = np.linspace(-5, 5, 20)
np.random.seed(1)

# %% [markdown]
# ### Random distributed noise

# %%
y = -5 + 3*x + 4 * np.random.normal(size=x.shape)

# %% [markdown]
# ### Creating a dataframe containing relevant variables

# %%
data = pd.DataFrame({'x': x, 'y':y})

# %% [markdown]
# # Specifying and fitting an OLS model

# %%
from statsmodels.formula.api import ols
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
model = smf.ols("y ~ x", data).fit()

# %% [markdown]
# # Observing data and comparing groups/categories

# %% [markdown]
# ## Inspecting the statistics of the model

# %%
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.804
# Model:                            OLS   Adj. R-squared:                  0.794
# Method:                 Least Squares   F-statistic:                     74.03
# Date:                Sun, 14 Jul 2024   Prob (F-statistic):           8.56e-08
# Time:                        02:37:37   Log-Likelihood:                -57.988
# No. Observations:                  20   AIC:                             120.0
# Df Residuals:                      18   BIC:                             122.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -5.5335      1.036     -5.342      0.000      -7.710      -3.357
# x              2.9369      0.341      8.604      0.000       2.220       3.654
# ==============================================================================
# Omnibus:                        0.100   Durbin-Watson:                   2.956
# Prob(Omnibus):                  0.951   Jarque-Bera (JB):                0.322
# Skew:                          -0.058   Prob(JB):                        0.851
# Kurtosis:                       2.390   Cond. No.                         3.03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # Comparison of IQ between male and female using Linear Model

# %%
data = pd.read_csv('brain_size.csv', sep=';', na_values=".")

# %%
model = ols("VIQ ~ Gender + 1", data=data).fit()

# %%
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    VIQ   R-squared:                       0.015
# Model:                            OLS   Adj. R-squared:                 -0.010
# Method:                 Least Squares   F-statistic:                    0.5969
# Date:                Sun, 14 Jul 2024   Prob (F-statistic):              0.445
# Time:                        02:37:39   Log-Likelihood:                -182.42
# No. Observations:                  40   AIC:                             368.8
# Df Residuals:                      38   BIC:                             372.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept        109.4500      5.308     20.619      0.000      98.704     120.196
# Gender[T.Male]     5.8000      7.507      0.773      0.445      -9.397      20.997
# ==============================================================================
# Omnibus:                       26.188   Durbin-Watson:                   1.709
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                3.703
# Skew:                           0.010   Prob(JB):                        0.157
# Kurtosis:                       1.510   Cond. No.                         2.62
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # Integer column to be treated as categorical

# %%
model = ols('VIQ ~ C(Gender)', data).fit()

# %% [markdown]
# ## Linking to t-test between different FSIQ and PIQ

# %%
data_fisq = pd.DataFrame({'iq': data['FSIQ'], 'type': 'fsiq'})
data_piq = pd.DataFrame({'iq': data['PIQ'], 'type': 'piq'})
data_long = pd.concat((data_fisq, data_piq))

# %%
print(data_long)
# Out:
#      iq  type
# 0   133  fsiq
# 1   140  fsiq
# 2   139  fsiq
# 3   133  fsiq
# 4   137  fsiq
# ..  ...   ...
# 35  128   piq
# 36  124   piq
# 37   94   piq
# 38   74   piq
# 39   89   piq
#
# [80 rows x 2 columns]

# %% [markdown]
# # OLS Regression

# %%
model = ols("iq ~ type", data_long).fit()

# %%
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     iq   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.010
# Method:                 Least Squares   F-statistic:                    0.2168
# Date:                Sun, 14 Jul 2024   Prob (F-statistic):              0.643
# Time:                        02:37:43   Log-Likelihood:                -364.35
# No. Observations:                  80   AIC:                             732.7
# Df Residuals:                      78   BIC:                             737.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept     113.4500      3.683     30.807      0.000     106.119     120.781
# type[T.piq]    -2.4250      5.208     -0.466      0.643     -12.793       7.943
# ==============================================================================
# Omnibus:                      164.598   Durbin-Watson:                   1.531
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                8.062
# Skew:                          -0.110   Prob(JB):                       0.0178
# Kurtosis:                       1.461   Cond. No.                         2.62
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # t-test results similar to regression results

# %%
stats.ttest_ind(data['FSIQ'], data['PIQ'])
# Out:
# TtestResult(statistic=np.float64(0.465637596380964), pvalue=np.float64(0.6427725009414841), df=np.float64(78.0))

# %% [markdown]
# # 3.1.3.2 Multiple Regression

# %% [markdown]
# ## Reading in iris data

# %%
data = pd.read_csv('iris.csv')

# %% [markdown]
# # OLS regression results

# %%
model = ols('sepal_width ~ name + petal_length', data).fit()

# %%
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            sepal_width   R-squared:                       0.478
# Model:                            OLS   Adj. R-squared:                  0.468
# Method:                 Least Squares   F-statistic:                     44.63
# Date:                Sun, 14 Jul 2024   Prob (F-statistic):           1.58e-20
# Time:                        02:37:48   Log-Likelihood:                -38.185
# No. Observations:                 150   AIC:                             84.37
# Df Residuals:                     146   BIC:                             96.41
# Df Model:                           3
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              2.9813      0.099     29.989      0.000       2.785       3.178
# name[T.versicolor]    -1.4821      0.181     -8.190      0.000      -1.840      -1.124
# name[T.virginica]     -1.6635      0.256     -6.502      0.000      -2.169      -1.158
# petal_length           0.2983      0.061      4.920      0.000       0.178       0.418
# ==============================================================================
# Omnibus:                        2.868   Durbin-Watson:                   1.753
# Prob(Omnibus):                  0.238   Jarque-Bera (JB):                2.885
# Skew:                          -0.082   Prob(JB):                        0.236
# Kurtosis:                       3.659   Cond. No.                         54.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # 3.1.3.3 ANOVA (Post HOC analysis testing) to see if significant variance

# %%
print(model.f_test([0, 1, -1, 0]))
# Out:
# <F test: F=3.2453353465741173, p=0.07369058781701415, df_denom=146, df_num=1>

# %% [markdown]
# # 3.1.4 Seaborn statistical exploration

# %% [markdown]
# ### Library imports

# %%
import urllib
import os
import urllib.request
from matplotlib import pyplot as plt
import matplotlib.pyplot as plt

# %%
import seaborn
import statsmodels.formula.api as smf

# %%
import pandas
if not os.path.exists('wages.txt'):
    # Download the file if it is not present
    urllib.request.urlretrieve('http://lib.stat.cmu.edu/datasets/CPS_85_Wages',
                               'wages.txt')

# %% [markdown]
# # Assigning names

# %%
names = [
    'EDUCATION: Number of years of education',
    'SOUTH: 1=Person lives in South, 0=Person lives elsewhere',
    'SEX: 1=Female, 0=Male',
    'EXPERIENCE: Number of years of work experience',
    'UNION: 1=Union member, 0=Not union member',
    'WAGE: Wage (dollars per hour)',
    'AGE: years',
    'RACE: 1=Other, 2=Hispanic, 3=White',
    'OCCUPATION: 1=Management, 2=Sales, 3=Clerical, 4=Service, 5=Professional, 6=Other',
    'SECTOR: 0=Other, 1=Manufacturing, 2=Construction',
    'MARR: 0=Unmarried,  1=Married',
]

short_names = [n.split(':')[0] for n in names]

data = pd.read_csv('wages.txt', skiprows=27, skipfooter=6, sep=None,
                   header=None, engine='python')  # Using engine='python' for skipfooter
data.columns = short_names
import numpy as np
data['WAGE'] = np.log10(data['WAGE'])

# %% [markdown]
# # 3.1.4.1 Scatter Matricies Data and Pairplots

# %%
print(data)
# Out:
#      EDUCATION  SOUTH  SEX  EXPERIENCE  UNION      WAGE  AGE  RACE  \
# 0            8      0    1          21      0  0.707570   35     2
# 1            9      0    1          42      0  0.694605   57     3
# 2           12      0    0           1      0  0.824126   19     3
# 3           12      0    0           4      0  0.602060   22     3
# 4           12      0    0          17      0  0.875061   35     3
# ..         ...    ...  ...         ...    ...       ...  ...   ...
# 529         18      0    0           5      0  1.055378   29     3
# 530         12      0    1          33      0  0.785330   51     1
# 531         17      0    1          25      1  1.366423   48     1
# 532         12      1    0          13      1  1.298416   31     3
# 533         16      0    0          33      0  1.186956   55     3
#
#      OCCUPATION  SECTOR  MARR
# 0             6       1     1
# 1             6       1     1
# 2             6       1     0
# 3             6       0     0
# 4             6       0     1
# ..          ...     ...   ...
# 529           5       0     0
# 530           5       0     1
# 531           5       0     1
# 532           5       0     1
# 533           5       1     1
#
# [534 rows x 11 columns]

# %%
seaborn.pairplot(data, vars=['WAGE', 'AGE', 'EDUCATION'],
                 kind='reg')  
seaborn.pairplot(data, vars=['WAGE', 'AGE', 'EDUCATION'],
                 kind='reg', hue='SEX') 
plt.suptitle('Effect of gender: 1=Female, 0=Male')
seaborn.pairplot(data, vars=['WAGE', 'AGE', 'EDUCATION'],
                 kind='reg', hue='RACE')
plt.suptitle('Effect of race: 1=Other, 2=Hispanic, 3=White')
seaborn.pairplot(data, vars=['WAGE', 'AGE', 'EDUCATION'],
                 kind='reg', hue='UNION')
plt.suptitle('Effect of union: 1=Union member, 0=Not union member')
# Out:
# Text(0.5, 0.98, 'Effect of union: 1=Union member, 0=Not union member')

# %%
plt.rcdefaults()

# %% [markdown]
# # 3.1.4.2 Univariate Regression plot

# %%
seaborn.lmplot(y='WAGE', x='EDUCATION', data=data)

# %% [markdown]
# # 3.1.5 Testing interactions between groups

# %%
seaborn.lmplot(y='WAGE', x='EDUCATION', hue = 'SEX', data=data)

# %%
result = smf.ols(formula=formula, data=data).fit()

# %%
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   wage   R-squared:                       0.938
# Model:                            OLS   Adj. R-squared:                  0.754
# Method:                 Least Squares   F-statistic:                     5.083
# Date:                Sun, 14 Jul 2024   Prob (F-statistic):              0.313
# Time:                        02:44:49   Log-Likelihood:                -9.9045
# No. Observations:                   5   AIC:                             27.81
# Df Residuals:                       1   BIC:                             26.25
# Df Model:                           3
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                  -40.0000     36.162     -1.106      0.468    -499.482     419.482
# gender[T.male]              31.1538     37.527      0.830      0.559    -445.673     507.981
# education                    5.0000      2.774      1.803      0.322     -30.241      40.241
# education:gender[T.male]    -2.6923      2.852     -0.944      0.518     -38.935      33.551
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.615
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.359
# Skew:                          -0.607   Prob(JB):                        0.836
# Kurtosis:                       2.500   Cond. No.                         521.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /srv/conda/envs/notebook/lib/python3.9/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "

# %% [markdown]
# # Unexpected results ^
